# %% [markdown]
# <a href="https://colab.research.google.com/github/shbnm93/Data-Science-Projects/blob/main/n11_webscraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from urllib.request import urlopen
import requests
import time
from bs4 import BeautifulSoup as bts

# %%
def getAndParseURL(url):
    result = requests.get(url ,headers={"User-Agent":"Chrome/96.0.4664.92"})
    soup = bts(result.text, 'html.parser')
    return soup

# %%
PAGE_LINKS = []
def getPageLinks() :
    for i in range(1,51) :
            PAGE_LINKS.append("https://www.n11.com/telefon-ve-aksesuarlari/cep-telefonu" + "?pg=" +str(i))
    return PAGE_LINKS
getPageLinks()
# Out:
# ['https://www.n11.com/telefon-ve-aksesuarlari/cep-telefonu?pg=1',
#  'https://www.n11.com/telefon-ve-aksesuarlari/cep-telefonu?pg=2',
#  'https://www.n11.com/telefon-ve-aksesuarlari/cep-telefonu?pg=3',
#  'https://www.n11.com/telefon-ve-aksesuarlari/cep-telefonu?pg=4',
#  'https://www.n11.com/telefon-ve-aksesuarlari/cep-telefonu?pg=5',
#  'https://www.n11.com/telefon-ve-aksesuarlari/cep-telefonu?pg=6',
#  'https://www.n11.com/telefon-ve-aksesuarlari/cep-telefonu?pg=7',
#  'https://www.n11.com/telefon-ve-aksesuarlari/cep-telefonu?pg=8',
#  'https://www.n11.com/telefon-ve-aksesuarlari/cep-telefonu?pg=9',
#  'https://www.n11.com/telefon-ve-aksesuarlari/cep-telefonu?pg=10',
#  'https://www.n11.com/telefon-ve-aksesuarlari/cep-telefonu?pg=11',
#  'https://www.n11.com/telefon-ve-aksesuarlari/cep-telefonu?pg=12',
#  'https://www.n11.com/telefon-ve-aksesuarlari/cep-telefonu?pg=13',
#  'https://www.n11.com/telefon-ve-aksesuarlari/cep-telefonu?pg=14',
# ...

# %%
PRICE = []
def getProductPrices():
  for pageLink in PAGE_LINKS:
      html = getAndParseURL(pageLink)
      for result in html.findAll("span",{"data-id":"494233542"}):
        PRICE.append(result.get("ins"))
  return PRICE
getProductPrices()
# Out:
# [None, None]

# %%
PRODUCT_LINKS = []
def getProductLinks():
  for pageLink in PAGE_LINKS:
      html = getAndParseURL(pageLink)
      for result in html.findAll("a",{"class":"plink"}):
        PRODUCT_LINKS.append(result.get("href"))
  return PRODUCT_LINKS
getProductLinks()
# Out:
# ['https://www.n11.com/urun/samsung-galaxy-m12-duos-128-gb-samsung-turkiye-garantili-2002230?magaza=samsungturkiye',
#  'https://www.n11.com/urun/xiaomi-redmi-note-10-pro-8-gb-ram-128-gb-xiaomi-turkiye-garantili-1967193?magaza=xiaomiturkiye',
#  'https://www.n11.com/urun/apple-iphone-11-64-gb-apple-turkiye-garantili-1109951?magaza=teknonet',
#  'https://www.n11.com/urun/apple-iphone-11-64-gb-apple-turkiye-garantili-1109951?magaza=selentelekom',
#  'https://www.n11.com/urun/xiaomi-redmi-note-10s-6-gb-128-gb-xiaomi-turkiye-garantili-2115599?magaza=shop11',
#  'https://www.n11.com/urun/samsung-galaxy-m12-duos-64-gb-samsung-turkiye-garantili-2002208?magaza=samsungturkiye',
#  'https://www.n11.com/urun/apple-iphone-13-128-gb-apple-turkiye-garantili-2141312?magaza=bittibitiyor',
#  'https://www.n11.com/urun/samsung-galaxy-m52-5g-128-gb-samsung-turkiye-garantili-2176145?magaza=samsungturkiye',
# ...

# %%
html = getAndParseURL("https://www.n11.com/urun/xiaomi-redmi-note-10s-6-gb-128-gb-xiaomi-turkiye-garantili-2115599?magaza=royal-bilgi")

# %%
html2 = getAndParseURL("https://www.n11.com/telefon-ve-aksesuarlari/cep-telefonu?pg=1")

# %%
html2.find("div",{"class":"proDetail"}).ins
# Out:
# <ins>3.539,00 <span content="TRY">TL</span> </ins>

# %%
html2.find("div",{"class":"proDetail"}).ins.text.replace(" TL ","").split(",")[0].replace(".","")
# Out:
# '3539'

# %%
html.find("div",{"class":"nameHolder"}).h1.text.strip()
# Out:
# 'Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türkiye Garantili)'

# %%
html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[0].find("p",{"class":"unf-prop-list-prop"}).text
# Out:
# ' 13 MP'

# %%
html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[1].find("p",{"class":"unf-prop-list-prop"}).text
# Out:
# ' Var'

# %%
html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[2].find("p",{"class":"unf-prop-list-prop"}).text
# Out:
# ' IP5X'

# %%
html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[3].find("p",{"class":"unf-prop-list-prop"}).text
# Out:
# ' Var'

# %%
html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[4].find("p",{"class":"unf-prop-list-prop"}).text
# Out:
# ' IPX3'

# %%
html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[5].find("p",{"class":"unf-prop-list-prop"}).text
# Out:
# ' Distribütör Garantili'

# %%
html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[6].find("p",{"class":"unf-prop-list-prop"}).text
# Out:
# ' Var'

# %%
html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[7].find("p",{"class":"unf-prop-list-prop"}).text
# Out:
# ' 74.5 MM'

# %%
html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[8].find("p",{"class":"unf-prop-list-prop"}).text
# Out:
# ' Var'

# %%
html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[9].find("p",{"class":"unf-prop-list-prop"}).text
# Out:
# ' 5000 mAh'

# %%
html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[10].find("p",{"class":"unf-prop-list-prop"}).text
# Out:
# ' Var'

# %%
html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[11].find("p",{"class":"unf-prop-list-prop"}).text
# Out:
# ' 6 GB'

# %%
html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[12].find("p",{"class":"unf-prop-list-prop"}).text
# Out:
# ' 64 MP'

# %%
RESULT = []
for result in PRODUCT_LINKS:

  product_name = html.find("div",{"class":"nameHolder"}).h1.text.strip()
  #price = html.find("div",{"class":"newPrice"}).find("ins",{"content":"4939.90"})
  Front_Camera_Resolution = html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[0].find("p",{"class":"unf-prop-list-prop"}).text
  Quick_Charge_Feature = html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[1].find("p",{"class":"unf-prop-list-prop"}).text
  Dustproof_Level = html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[2].find("p",{"class":"unf-prop-list-prop"}).text
  Double_simcart = html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[3].find("p",{"class":"unf-prop-list-prop"}).text
  Waterproof_Level = html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[4].find("p",{"class":"unf-prop-list-prop"}).text
  Warranty_Type = html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[5].find("p",{"class":"unf-prop-list-prop"}).text
  Dust_Resistance = html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[6].find("p",{"class":"unf-prop-list-prop"}).text
  Width = html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[7].find("p",{"class":"unf-prop-list-prop"}).text
  GPS = html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[8].find("p",{"class":"unf-prop-list-prop"}).text
  Battery_Capacity = html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[9].find("p",{"class":"unf-prop-list-prop"}).text
  Memory_Card_Support = html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[10].find("p",{"class":"unf-prop-list-prop"}).text
  Memory_Capacity = html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[11].find("p",{"class":"unf-prop-list-prop"}).text
  Back_Camera_Resolution = html.find("ul", {"class":"unf-prop-list"}).findAll("li",{"class":"unf-prop-list-item"})[12].find("p",{"class":"unf-prop-list-prop"}).text
  RESULT.append([product_name,Front_Camera_Resolution,Quick_Charge_Feature,Dustproof_Level,Double_simcart,Waterproof_Level,Warranty_Type,Dust_Resistance,Width,GPS,Battery_Capacity,Memory_Card_Support,Memory_Capacity,Back_Camera_Resolution])

columns = ["product_name","Front_Camera_Resolution", "Quick_Charge_Feature","Dustproof_Level","Double_simcart","Waterproof_Level","Warranty_Type","Dust_Resistance","Width","GPS","Battery_Capacity","Memory_Card_Support","Memory_Capacity","Back_Camera_Resolution"]
df = pd.DataFrame.from_records(RESULT, columns = columns)

# %%
df.head(20)
# Out:
#                                          product_name Front_Camera_Resolution  \
# 0   Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...                   13 MP
# 1   Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...                   13 MP
# 2   Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...                   13 MP
# 3   Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...                   13 MP
# 4   Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...                   13 MP
# 5   Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...                   13 MP
# 6   Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...                   13 MP
# 7   Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...                   13 MP
# 8   Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...                   13 MP
# 9   Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...                   13 MP
# 10  Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...                   13 MP
# ...

# %%
df.tail(20)
# Out:
#                                            product_name  \
# 1380  Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...
# 1381  Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...
# 1382  Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...
# 1383  Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...
# 1384  Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...
# 1385  Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...
# 1386  Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...
# 1387  Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...
# 1388  Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...
# 1389  Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...
# 1390  Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...
# 1391  Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...
# 1392  Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...
# 1393  Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...
# 1394  Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...
# 1395  Xiaomi Redmi Note 10S 6 GB 128 GB (Xiaomi Türk...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393 entries, 0 to 1392
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   product_name             1393 non-null   object
#  1   Front_Camera_Resolution  1393 non-null   object
#  2   Quick_Charge_Feature     1393 non-null   object
#  3   Dustproof_Level          1393 non-null   object
#  4   Double_simcart           1393 non-null   object
#  5   Waterproof_Level         1393 non-null   object
#  6   Warranty_Type            1393 non-null   object
#  7   Dust_Resistance          1393 non-null   object
#  8   Width                    1393 non-null   object
#  9   GPS                      1393 non-null   object
#  10  Battery_Capacity         1393 non-null   object
#  11  Memory_Card_Support      1393 non-null   object
#  12  Memory_Capacity          1393 non-null   object
#  13  Back_Camera_Resolution   1393 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# product_name               0
# Front_Camera_Resolution    0
# Quick_Charge_Feature       0
# Dustproof_Level            0
# Double_simcart             0
# Waterproof_Level           0
# Warranty_Type              0
# Dust_Resistance            0
# Width                      0
# GPS                        0
# Battery_Capacity           0
# Memory_Card_Support        0
# Memory_Capacity            0
# Back_Camera_Resolution     0
# dtype: int64

# %%
df.Quick_Charge_Feature
# Out:
# 0        Var
# 1        Var
# 2        Var
# 3        Var
# 4        Var
#         ...
# 1395     Var
# 1396     Var
# 1397     Var
# 1398     Var
# 1399     Var
# Name: Quick_Charge_Feature, Length: 1400, dtype: object
